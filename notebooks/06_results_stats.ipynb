# %% [markdown]
# # 06 — Análisis de resultados
#
# - Tablas de métricas por método y semilla.
# - Wilcoxon STFT vs CWT (CNN y SVM).
# - Bootstrap CI de accuracy.
# - Figuras finales para el informe.

# %%
# %load_ext autoreload
# %autoreload 2
import sys; sys.path.append('..')
import json, numpy as np
from pathlib import Path
from src.stats import wilcoxon_paired, bootstrap_ci

RES = Path('../results')
# Cargar fold_results.json de stft y cwt para CNN
# Calcular Wilcoxon, CI y reportar
