# %% [markdown]
# # 05 — Inspección de mapas Grad-CAM y vanilla saliency
#
# - Cargar mapas agregados de `data/derivatives/saliency/`.
# - Superponer al modulation spectrum medio.
# - Comparar STFT vs CWT cualitativamente.

# %%
# %load_ext autoreload
# %autoreload 2
import sys; sys.path.append('..')
import numpy as np
import matplotlib.pyplot as plt
from src.utils.viz import plot_saliency_overlay

# Placeholder: rellenar con paths reales tras correr 04_extract_saliency_features.py
# sal_AD = np.load('../data/derivatives/saliency/stft_200_seed0/saliency_AD.npy')
# sal_HC = np.load('../data/derivatives/saliency/stft_200_seed0/saliency_HC.npy')
